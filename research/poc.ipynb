# %%
import pandas as pd
pd.__version__
# Out:
# '0.25.3'

# %%
file_path = "..\data\CTBM.raw.xlsx"

# %%
pd.read_excel(file_path, sheet_name="Codes")
# Out:
#                                            Descriptions        Fk_CodeId  \
# 0          The root of the Harmonized System code tree.              NaN
# 1                         LIVE ANIMALS; ANIMAL PRODUCTS         hs_dafn_
# 2                                         Live animals.      hs_dafn_+01
# 3                Live horses, asses, mules and hinnies.       hs_dafn_01
# 4                                             -Horses :     hs_dafn_0101
# ...                                                 ...              ...
# 8337  - Bona fide gifts to a value not exceeding $30...  hs_dafn_9803000
# 8338         - Machines for additive manufacturing (3-D  hs_dafn_9803000
# 8339    - Products containing nicotine intended for the  hs_dafn_9803000
# 8340  - Electronic cigarettes and similar personal e...  hs_dafn_9803000
# 8341                                            - Other  hs_dafn_9803000
#
#       Is_System_Defined  Is_Taxable  Zero_Padded_Count  HasChildren  \
# ...
